# %%
# Import libraries 
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
phool = sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
phool = sns.load_dataset("iris")
phool

# draw a barplot
sns.barplot(x = "species", y = "sepal_width", data = phool)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
phool = sns.load_dataset("iris")
phool

# draw a barplot
sns.barplot(x = "species", y = "petal_length", data = phool)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "who", y = "alone", hue = "sex", data = kashti)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], color = "red")
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_4592\1200566401.py:8: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], color = "red")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], color = "yellow")
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_4592\3225922577.py:8: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:yellow'` for the same effect.
#
#   sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], color = "yellow")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], estimator = mean)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import median 
# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], estimator = median)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean
# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], estimator = mean, saturation= 0.2)
plt.show()

# %%
# saturation means graph ka color change hoga
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "sex", y = "alone", hue = "who", data = kashti, order = ["female", "male"], estimator = mean, saturation=1)
plt.show()

# %% [markdown]
# ## Horizontal plot

# %%
# only change the x and y axis values, in placce of ci can also be used the word error bars
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
kashti
# draw a barplot
sns.barplot(x = "fare", y = "class", hue = "who", data = kashti,saturation=1, ci= None)
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_4592\118979049.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = "fare", y = "class", hue = "who", data = kashti,saturation=1, ci= None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
# draw a barplot
sns.barplot(x = "class", y = "fare", data = kashti,
           linewidth=3, facecolor=(1,1,1,0.2),
           errcolor="0.5",edgecolor="0")
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_19452\2476465423.py:7: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.5'}` instead.
#
#   sns.barplot(x = "class", y = "fare", data = kashti,

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
# draw a barplot
sns.barplot(x = "class", y = "fare", data = kashti,
           linewidth=3, facecolor=(1,1,1,0.2),
           errcolor="0.1",edgecolor="0")
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_4592\3069119900.py:7: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.1'}` instead.
#
#   sns.barplot(x = "class", y = "fare", data = kashti,

# %%
# here the graph showing nothing bcz the edge color is 1 and here 1 used as white and 0 used as black and 0.5 is for grey color
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
# draw a barplot
sns.barplot(x = "class", y = "fare", data = kashti,
           linewidth=3, facecolor=(1,1,1,0.2),
           errcolor="0.5",edgecolor="1")
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_19452\1103958682.py:8: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.5'}` instead.
#
#   sns.barplot(x = "class", y = "fare", data = kashti,

# %%
# here we have changes the face color
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean 
# Load data
kashti = sns.load_dataset("titanic")
# draw a barplot
sns.barplot(x = "class", y = "fare", data = kashti,
           linewidth=3, facecolor=(0.3,0.1,0.3,0.2),
           errcolor="0.5",edgecolor="0")
plt.show()
# Out:
# C:\Users\Ammara\AppData\Local\Temp\ipykernel_19452\710608865.py:8: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.5'}` instead.
#
#   sns.barplot(x = "class", y = "fare", data = kashti,

# %%
import sys
if len(sys.argv) < 2:
    print("too many arguments")
elif len(sys.argv) > 2:
    print("few arguments")
else:
    print("hello, my name is", Ammara)
# Out:
# few arguments
